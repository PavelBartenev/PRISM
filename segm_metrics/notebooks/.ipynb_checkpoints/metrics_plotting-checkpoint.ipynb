# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
metrics_dir = '../metrics'
filenames = os.listdir(metrics_dir)

filenames
# Out:
# ['coverage_v2v-t1_all@20.09.2024-17@fold-0_tb.csv',
#  'dice_v2v_t1_augm_i2sb_3dunet_masks_cond@23_10_2024_03@fold_0_tb.csv',
#  'dice_v2v-t1_augm_i2sb_3dunet_masks@23.10.2024-03@fold-0_tb.csv',
#  'coverage_v2v-t1_augm_i2sb_sphere@17.10.2024-22@fold-0_tb.csv',
#  'dice_v2v-t1_augm_i2sb_sphere@17.10.2024-22@fold-0_tb.csv',
#  'dice_v2v-t1_all@20.09.2024-17@fold-0_tb.csv',
#  'coverage_v2v_t1_augm_i2sb_3dunet_masks@23_10_2024_03@fold_0_tb.csv',
#  'coverage_v2v_t1_augm_i2sb_3dunet_masks_cond@23_10_2024_03@fold_0.csv']

# %%
def draw_metrics(data, labels, title):
    plt.figure(figsize=(15, 7))
    for arr, title, label in zip(data, titles, labels):
        plt.plot(arr, label=label)

    plt.title(title)
    plt.legend()
    plt.show()

# %%
coverage_filenames = [filename for filename in filenames if 'coverage' in filename]
dice_filenames = [filename for filename in filenames if 'dice' in filename]

data = [list(pd.read_csv(os.path.join(metrics_dir, filename))['Value']) for filename in coverage_filenames]
labels =
# Out:
# [[0.6698406934738159,
#   0.0932707414031028,
#   0.0519899874925613,
#   0.0547131262719631,
#   0.0692595914006233,
#   0.0678201243281364,
#   0.0757370963692665,
#   0.0565348491072654,
#   0.0673191621899604,
#   0.0492875017225742,
#   0.0651434659957885,
#   0.0787739604711532,
#   0.0638208612799644,
#   0.07217488437891,
#   0.0694746896624565,
#   0.0847470611333847,
#   0.0672108903527259,
#   0.0651031509041786,
#   0.0732591077685356,
#   0.071733072400093,
#   0.0761867314577102,
#   0.0436423271894454,
#   0.085172101855278,
#   0.0703062638640403,
#   0.0845779478549957,
#   0.0790924951434135,
#   0.075274720788002,
#   0.0687654986977577,
#   0.1005869209766388,
#   0.0580334924161434,
#   0.0926541537046432,
#   0.0693795531988143,
#   0.0654965490102768,
#   0.078940100967884,
#   0.1115173026919364,
#   0.1383209079504013,
#   0.0718665122985839,
#   0.0845964923501014,
#   0.0992812067270279,
#   0.1452140063047409,
#   0.1026132479310035,
# ...
